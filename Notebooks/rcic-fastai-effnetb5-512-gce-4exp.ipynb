# %% [markdown]
# # Load modules

# %%
# %cd ~/Workspace/kaggle-2019Q3-cellular/
# Out:
# /home/chengjiun/Workspace/kaggle-2019Q3-cellular

# %%
import os
import numpy as np
import pandas as pd

from fastai.vision import *
BASE_DIR = '../DATA/kaggle-2019Q3-cellular/'


def open_rcic_image(fn):
    images = []
    for i in range(6):
        file_name = fn+str(i+1)+'.png'
        im = cv2.imread(file_name)
        if im is None: 
            print(f'file reading failed {file_name}')
        
        im = cv2.cvtColor(im, cv2.COLOR_RGB2GRAY)
        images.append(im)
    image = np.dstack(images)
    #print(pil2tensor(image, np.float32).shape)#.div_(255).shape)
    return Image(pil2tensor(image, np.float32).div_(255))
  
class MultiChannelImageList(ImageList):
    def open(self, fn):
        return open_rcic_image(fn)
    
def image2np(image:Tensor)->np.ndarray:
    "Convert from torch style `image` to numpy/matplotlib style."
    res = image.cpu().permute(1,2,0).numpy()
    if res.shape[2]==1:
        return res[...,0]  
    elif res.shape[2]>3:
        #print(res.shape)
        #print(res[...,:3].shape)
        return res[...,:3]
    else:
        return res

vision.image.image2np = image2np

# %% [markdown]
# ## efficientnet

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline  
from sklearn.model_selection import StratifiedKFold
from joblib import load, dump
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
import cv2
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision import models as md
from torch import nn
from torch.nn import functional as F
import scipy as sp
import re
import math
import collections
from functools import partial
from torch.utils import model_zoo
from sklearn import metrics
from collections import Counter
import json

# %%
from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import Conv2dStaticSamePadding
model = EfficientNet.from_pretrained('efficientnet-b6', num_classes=1108) 

def get_model_params(model_name, override_params):
    """ Get the block args and global params for a given model """
    if model_name.startswith('efficientnet'):
        w, d, s, p = efficientnet_params(model_name)
        # note: all models have drop connect rate = 0.2
        blocks_args, global_params = efficientnet(
            width_coefficient=w, depth_coefficient=d, dropout_rate=p, image_size=s)
    else:
        raise NotImplementedError('model name is not pre-defined: %s' % model_name)
    if override_params:
        # ValueError will be raised here if override_params has fields not included in global_params.
        global_params = global_params._replace(**override_params)
    return blocks_args, global_params


url_map = {
    'efficientnet-b0': 'http://storage.googleapis.com/public-models/efficientnet-b0-08094119.pth',
    'efficientnet-b1': 'http://storage.googleapis.com/public-models/efficientnet-b1-dbc7070a.pth',
    'efficientnet-b2': 'http://storage.googleapis.com/public-models/efficientnet-b2-27687264.pth',
    'efficientnet-b3': 'http://storage.googleapis.com/public-models/efficientnet-b3-c8376fa2.pth',
    'efficientnet-b4': 'http://storage.googleapis.com/public-models/efficientnet-b4-e116e8b3.pth',
    'efficientnet-b5': 'http://storage.googleapis.com/public-models/efficientnet-b5-586e6cc6.pth',
    'efficientnet-b6': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b6-c76e70fd.pth',
    'efficientnet-b7': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b7-dcc49843.pth',
}

def load_pretrained_weights(model, model_name, load_fc=True):
    """ Loads pretrained weights, and downloads if loading for the first time. """
    state_dict = model_zoo.load_url(url_map[model_name])
    if load_fc:
        model.load_state_dict(state_dict)
    else:
        state_dict.pop('_fc.weight')
        state_dict.pop('_fc.bias')
        res = model.load_state_dict(state_dict, strict=False)
        assert str(res.missing_keys) == str(['_fc.weight', '_fc.bias']), 'issue loading pretrained weights'
    print('Loaded pretrained weights for {}'.format(model_name))
            

# Set seed fol all
def seed_everything(seed=1358):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
    


seed_everything()
# Out:
# Loaded pretrained weights for efficientnet-b6

# %% [markdown]
# ## utils

# %%
#lazy calculation of stats
pixel_stats = pd.read_csv(f'{BASE_DIR}/pixel_stats.csv')
channel1_mean = pixel_stats.iloc[::6,:]['mean'].mean()
channel2_mean = pixel_stats.iloc[1::6,:]['mean'].mean()
channel3_mean = pixel_stats.iloc[2::6,:]['mean'].mean()
channel4_mean = pixel_stats.iloc[3::6,:]['mean'].mean()
channel5_mean = pixel_stats.iloc[4::6,:]['mean'].mean()
channel6_mean = pixel_stats.iloc[5::6,:]['mean'].mean()


channel1_std = pixel_stats.iloc[::6,:]['std'].mean()
channel2_std = pixel_stats.iloc[1::6,:]['std'].mean()
channel3_std = pixel_stats.iloc[2::6,:]['std'].mean()
channel4_std = pixel_stats.iloc[3::6,:]['std'].mean()
channel5_std = pixel_stats.iloc[4::6,:]['std'].mean()
channel6_std = pixel_stats.iloc[5::6,:]['std'].mean()
stats = (torch.Tensor([channel1_mean,channel2_mean,channel3_mean,channel4_mean,channel5_mean,channel6_mean])/255,torch.Tensor([channel1_std,channel2_std,channel3_std,channel4_std,channel5_std,channel6_std])/255)
print(stats)
# Out:
# (tensor([0.0229, 0.0611, 0.0396, 0.0391, 0.0219, 0.0356]), tensor([0.0271, 0.0492, 0.0219, 0.0292, 0.0183, 0.0193]))

# %% [markdown]
# ## Loading and formatting data
#
# Here I will load the csv into the DataFrame, and create a column in the DataFrame with the path to the corresponding image (`generate_df`)

# %%
train_df = pd.read_csv(f'{BASE_DIR}/train.csv')
train_df.head(10)
# Out:
#           id_code experiment  plate well  sirna
# 0  HEPG2-01_1_B03   HEPG2-01      1  B03    513
# 1  HEPG2-01_1_B04   HEPG2-01      1  B04    840
# 2  HEPG2-01_1_B05   HEPG2-01      1  B05   1020
# 3  HEPG2-01_1_B06   HEPG2-01      1  B06    254
# 4  HEPG2-01_1_B07   HEPG2-01      1  B07    144
# 5  HEPG2-01_1_B08   HEPG2-01      1  B08    503
# 6  HEPG2-01_1_B09   HEPG2-01      1  B09    188
# 7  HEPG2-01_1_B10   HEPG2-01      1  B10    700
# 8  HEPG2-01_1_B11   HEPG2-01      1  B11   1100
# 9  HEPG2-01_1_B12   HEPG2-01      1  B12    611

# %%
from sklearn.model_selection import train_test_split


exp_list = ['HEPG2', 'HUVEC', 'RPE', 'U2OS']
def generate_df(train_df,sample_num=[1,2],exp=None, test_size=None, random_state=42):
    train_df['is_valid'] = False
    if exp is not None:
        train_df = train_df[train_df['exp'] == exp]
        print(f'extract experiment: {exp}, number of train data {len(train_df)}')
    if test_size is not None:
        sub_train_df, sub_test_df = train_test_split(train_df, test_size=test_size, random_state=random_state)
        sub_test_df.loc[:, 'is_valid'] = True
        train_df = pd.concat([sub_train_df, sub_test_df], axis=0, sort=False)
    
    temp_df = train_df.drop(columns=['id_code','experiment','plate','well'])
    res_df = pd.DataFrame()
    for s in sample_num:
        temp_df['path'] = (train_df['experiment'].str.cat(train_df['plate'].astype(str)
                                                .str.cat(train_df['well'],sep='/'),sep='/Plate') + '_s'+str(s) + '_w')
        
        temp_df = temp_df.reindex(columns=['path','sirna', 'is_valid'])
        if len(res_df) ==0:
            res_df = temp_df.copy(deep=True)
        else:
            res_df = pd.concat([temp_df, res_df], axis=0, sort=False)
            
    return res_df

proc_train_all_df = generate_df(train_df, sample_num=[1,2], exp=None, test_size=0.1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
proc_train_all_df.head(10)
# Out:
#                            path  sirna  is_valid
# 24735  HUVEC-16/Plate2/H14_s2_w    694     False
# 33693   U2OS-01/Plate2/M13_s2_w    128     False
# 20160  HUVEC-12/Plate1/M12_s2_w    272     False
# 24447  HUVEC-16/Plate1/G22_s2_w    450     False
# 8517   HUVEC-01/Plate3/L20_s2_w    255     False
# 5686   HEPG2-06/Plate1/I17_s2_w    459     False
# 35838   U2OS-03/Plate2/I21_s2_w    639     False
# 24541  HUVEC-16/Plate1/L18_s2_w    162     False
# 23079  HUVEC-14/Plate4/H02_s2_w    334     False
# 5186   HEPG2-05/Plate3/L11_s2_w     48     False

# %%
il = MultiChannelImageList.from_df(df=proc_train_all_df,path='../DATA/kaggle-2019Q3-cellular/train/')

# %% [markdown]
# ## Creating and Training a Model

# %% [markdown]
# I will use a pretrained ResNet. I have to now adjust the CNN arch to take in 6 channels as opposed to the usual 3 channels:

# %%
"""Inspired by https://github.com/wdhorton/protein-atlas-fastai/blob/master/resnet.py"""

import torchvision
RESNET_MODELS = {
    34: torchvision.models.resnet34,
    50: torchvision.models.resnet50,
    101: torchvision.models.resnet101,
    152: torchvision.models.resnet152,
    '101x': torchvision.models.resnext101_32x8d,
}


def resnet_multichannel(depth=50,pretrained=True,num_classes=1108,num_channels=6):
    model = RESNET_MODELS[depth](pretrained=pretrained)
    w = model.conv1.weight
    model.conv1 = nn.Conv2d(num_channels, 64, kernel_size=7, stride=2, padding=3,
                           bias=False)
    model.conv1.weight = nn.Parameter(torch.cat((w,torch.zeros(64,num_channels-3,7,7)),dim=1))
    return model

def efficientnetb4_multichannel(name='efficientnet-b4', pretrained=True, num_classes=1108, num_channels=6):
    model = EfficientNet.from_pretrained(name, num_classes)
    load_pretrained_weights(model,model_name=name, load_fc=False)
    w = model._conv_stem.weight
    model._conv_stem = Conv2dStaticSamePadding(num_channels, 48, kernel_size=3, 
                                               image_size=image_size, stride=2, padding=3)
    model._conv_stem.weight = nn.Parameter(torch.cat((w,torch.zeros(48,num_channels-3,3,3)),dim=1))
    return model

def efficientnetb6_multichannel(name='efficientnet-b6', pretrained=True, num_classes=1108, num_channels=6):
    model = EfficientNet.from_pretrained(name, num_classes)
    load_pretrained_weights(model,model_name=name, load_fc=False)
    w = model._conv_stem.weight
    model._conv_stem = Conv2dStaticSamePadding(num_channels, 56, kernel_size=3, 
                                               image_size=image_size, stride=2, padding=3)
    model._conv_stem.weight = nn.Parameter(torch.cat((w,torch.zeros(56,num_channels-3,3,3)),dim=1))
    return model

# %%
image_size=512
def resnet34(pretrained,num_channels=6):
    return resnet_multichannel(depth=50,pretrained=pretrained,num_channels=num_channels)

def resnet50(pretrained,num_channels=6):
    return resnet_multichannel(depth=50,pretrained=pretrained,num_channels=num_channels)

def resnext101(pretrained,num_channels=6):
    return resnet_multichannel(depth='101x',pretrained=pretrained,num_channels=num_channels)

effnetb4 = efficientnetb4_multichannel('efficientnet-b4', pretrained=True,num_channels=6)

effnetb6 = efficientnetb6_multichannel('efficientnet-b6', pretrained=True,num_channels=6)

def _resnet_split(m): return (m[0][6],m[1])
# Out:
# Loaded pretrained weights for efficientnet-b4
# Loaded pretrained weights for efficientnet-b4
# Loaded pretrained weights for efficientnet-b6
# Loaded pretrained weights for efficientnet-b6

# %%
"""From https://www.kaggle.com/leighplt/densenet121-pytorch"""
def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size).item())
        return torch.Tensor(np.array(res))

# %% [markdown]
# Let's create our Learner:

# %%
from optim.ranger import Ranger
optar = partial(Ranger)

# %%
# 1080Ti 9G: img size=384, efficientnet-b4, bs=16
# 4Ti
exp_list = ['HEPG2', 'HUVEC', 'RPE', 'U2OS']
image_size=512
tfms = get_transforms(do_flip=True, flip_vert=True,
                      max_lighting=0.2, p_lighting=0.5, 
                      max_warp=0., max_rotate=20., max_zoom=1.0)

for exp in exp_list:

    proc_train_exp_df = generate_df(train_df, sample_num=[1,2], exp=exp, test_size=0.1)
    data = (MultiChannelImageList.from_df(df=proc_train_exp_df,path='../DATA/kaggle-2019Q3-cellular/train/')
            .split_from_df(col=2)
            .label_from_df()
            .transform(tfms,size=image_size)
            .databunch(bs=8,num_workers=8)
            .normalize(stats)
           )

    learn = Learner(data, 
                    effnetb6, opt_func=optar,
                    metrics = [accuracy], 
                    model_dir='./fastaimodel').to_fp16()
    # learn.model = torch.nn.DataParallel(learn.model)
    learn.path = Path('./effb6-gce')
    learn.load('effnetb6-512-stage2-best')
    learn.path = Path('./effb6-4exps-gce')
    
    learn.unfreeze()
    learn.fit_one_cycle(10,1e-5, callbacks=[SaveModelCallback(learn, every='improvement', monitor='accuracy')])
    
    learn.save(f'effnetb6-{exp}-512-stage2')
    learn.export()

# %% [markdown]
# ## Inference and Submission Generation

# %%
def generate_submission(preds_score, name='submission-effB4-384-singlesite.csv'):
    submission_df = pd.read_csv(f'{BASE_DIR}/sample_submission.csv')
    result = preds_score.argmax(dim=-1)
    submission_df.sirna = result.numpy().astype(int)
    submission_df.to_csv(name,index=False)
    print(f'write to submission_df {name}')
    return submission_df

# %% [markdown]
# ###  all data

# %%
proc_train_all_df = generate_df(train_df, sample_num=[1,2], exp=None, test_size=0.1)

image_size=512
tfms = get_transforms(do_flip=True, flip_vert=True,
                      max_lighting=0.2, p_lighting=0.5, 
                      max_warp=0., max_rotate=20., max_zoom=1.0)

data = (MultiChannelImageList.from_df(df=proc_train_all_df,path='../DATA/kaggle-2019Q3-cellular/train/')
        .split_from_df(col=2)
        .label_from_df()
        .transform(tfms,size=image_size)
        .databunch(bs=8,num_workers=8)
        .normalize(stats)
       )
learn.load('effnetb6-512-stage2-best')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (29212 items)
# x: MultiChannelImageList
# Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512)
# y: CategoryList
# 295,860,439,361,683
# Path: ../DATA/kaggle-2019Q3-cellular/train;
#
# Valid: LabelList (7303 items)
# x: MultiChannelImageList
# Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512),Image (6, 512, 512)
# y: CategoryList
# 209,961,903,419,850
# Path: ../DATA/kaggle-2019Q3-cellular/train;
#
# Test: None, model=EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     6, 56, kernel_size=(3, 3), stride=(2, 2), padding=(3, 3)
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         56, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (39): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (40): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (41): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
# ...
#   (303): ParameterModule()
#   (304): Identity()
#   (305): ParameterModule()
#   (306): ParameterModule()
#   (307): Identity()
#   (308): ParameterModule()
#   (309): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (310): Identity()
#   (311): ParameterModule()
#   (312): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (313): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (314): ParameterModule()
#   (315): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (316): Identity()
#   (317): ParameterModule()
#   (318): ParameterModule()
#   (319): Identity()
#   (320): ParameterModule()
#   (321): ParameterModule()
#   (322): Identity()
#   (323): ParameterModule()
#   (324): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (325): Identity()
#   (326): ParameterModule()
#   (327): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (328): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (329): ParameterModule()
#   (330): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (331): Identity()
#   (332): ParameterModule()
#   (333): ParameterModule()
#   (334): Identity()
#   (335): ParameterModule()
#   (336): ParameterModule()
#   (337): Identity()
#   (338): ParameterModule()
#   (339): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (340): Identity()
#   (341): ParameterModule()
#   (342): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (343): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (344): ParameterModule()
#   (345): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (346): Identity()
#   (347): ParameterModule()
#   (348): ParameterModule()
#   (349): Identity()
#   (350): ParameterModule()
#   (351): ParameterModule()
#   (352): Identity()
#   (353): ParameterModule()
#   (354): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): Identity()
#   (356): ParameterModule()
#   (357): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (358): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (359): ParameterModule()
#   (360): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (361): Identity()
#   (362): ParameterModule()
#   (363): ParameterModule()
#   (364): Identity()
#   (365): ParameterModule()
#   (366): ParameterModule()
#   (367): Identity()
#   (368): ParameterModule()
#   (369): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (370): Identity()
#   (371): ParameterModule()
#   (372): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (373): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (374): ParameterModule()
#   (375): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (376): Identity()
#   (377): ParameterModule()
#   (378): ParameterModule()
#   (379): Identity()
#   (380): ParameterModule()
#   (381): ParameterModule()
#   (382): Identity()
#   (383): ParameterModule()
#   (384): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (385): Identity()
#   (386): ParameterModule()
#   (387): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (388): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (389): ParameterModule()
#   (390): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (391): Identity()
#   (392): ParameterModule()
#   (393): ParameterModule()
#   (394): Identity()
#   (395): ParameterModule()
#   (396): ParameterModule()
#   (397): Identity()
#   (398): ParameterModule()
#   (399): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (400): Identity()
#   (401): ParameterModule()
#   (402): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (404): ParameterModule()
#   (405): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): ParameterModule()
#   (412): Identity()
#   (413): ParameterModule()
#   (414): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (415): Identity()
#   (416): ParameterModule()
#   (417): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (418): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (419): ParameterModule()
#   (420): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (421): Identity()
#   (422): ParameterModule()
#   (423): ParameterModule()
#   (424): Identity()
#   (425): ParameterModule()
#   (426): ParameterModule()
#   (427): Identity()
#   (428): ParameterModule()
#   (429): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (430): Identity()
#   (431): ParameterModule()
#   (432): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (433): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (434): ParameterModule()
#   (435): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (436): Identity()
#   (437): ParameterModule()
#   (438): ParameterModule()
#   (439): Identity()
#   (440): ParameterModule()
#   (441): ParameterModule()
#   (442): Identity()
#   (443): ParameterModule()
#   (444): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (445): Identity()
#   (446): ParameterModule()
#   (447): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (448): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (449): ParameterModule()
#   (450): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (451): Identity()
#   (452): ParameterModule()
#   (453): ParameterModule()
#   (454): Identity()
#   (455): ParameterModule()
#   (456): ParameterModule()
#   (457): Identity()
#   (458): ParameterModule()
#   (459): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (460): Identity()
#   (461): ParameterModule()
#   (462): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (463): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (464): ParameterModule()
#   (465): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (466): Identity()
#   (467): ParameterModule()
#   (468): ParameterModule()
#   (469): Identity()
#   (470): ParameterModule()
#   (471): ParameterModule()
#   (472): Identity()
#   (473): ParameterModule()
#   (474): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (475): Identity()
#   (476): ParameterModule()
#   (477): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (478): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (479): ParameterModule()
#   (480): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (481): Identity()
#   (482): ParameterModule()
#   (483): ParameterModule()
#   (484): Identity()
#   (485): ParameterModule()
#   (486): ParameterModule()
#   (487): Identity()
#   (488): ParameterModule()
#   (489): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (490): Identity()
#   (491): ParameterModule()
#   (492): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (493): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (494): ParameterModule()
#   (495): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (496): Identity()
#   (497): ParameterModule()
#   (498): ParameterModule()
#   (499): Identity()
#   (500): ParameterModule()
#   (501): ParameterModule()
#   (502): Identity()
#   (503): ParameterModule()
#   (504): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (505): Identity()
#   (506): ParameterModule()
#   (507): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (508): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (509): ParameterModule()
#   (510): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (511): Identity()
#   (512): ParameterModule()
#   (513): ParameterModule()
#   (514): Identity()
#   (515): ParameterModule()
#   (516): ParameterModule()
#   (517): Identity()
#   (518): ParameterModule()
#   (519): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (520): Identity()
#   (521): ParameterModule()
#   (522): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (523): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (524): ParameterModule()
#   (525): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (526): Identity()
#   (527): ParameterModule()
#   (528): ParameterModule()
#   (529): Identity()
#   (530): ParameterModule()
#   (531): ParameterModule()
#   (532): Identity()
#   (533): ParameterModule()
#   (534): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (535): Identity()
#   (536): ParameterModule()
#   (537): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (538): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (539): ParameterModule()
#   (540): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (541): Identity()
#   (542): ParameterModule()
#   (543): ParameterModule()
#   (544): Identity()
#   (545): ParameterModule()
#   (546): ParameterModule()
#   (547): Identity()
#   (548): ParameterModule()
#   (549): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (550): Identity()
#   (551): ParameterModule()
#   (552): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (553): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (554): ParameterModule()
#   (555): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (556): Identity()
#   (557): ParameterModule()
#   (558): ParameterModule()
#   (559): Identity()
#   (560): ParameterModule()
#   (561): ParameterModule()
#   (562): Identity()
#   (563): ParameterModule()
#   (564): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (565): Identity()
#   (566): ParameterModule()
#   (567): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (568): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (569): ParameterModule()
#   (570): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (571): Identity()
#   (572): ParameterModule()
#   (573): ParameterModule()
#   (574): Identity()
#   (575): ParameterModule()
#   (576): ParameterModule()
#   (577): Identity()
#   (578): ParameterModule()
#   (579): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (580): Identity()
#   (581): ParameterModule()
#   (582): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (583): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (584): ParameterModule()
#   (585): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (586): Identity()
#   (587): ParameterModule()
#   (588): ParameterModule()
#   (589): Identity()
#   (590): ParameterModule()
#   (591): ParameterModule()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (595): Identity()
#   (596): ParameterModule()
#   (597): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (599): ParameterModule()
#   (600): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (601): Identity()
#   (602): ParameterModule()
#   (603): ParameterModule()
#   (604): Identity()
#   (605): ParameterModule()
#   (606): ParameterModule()
#   (607): Identity()
#   (608): ParameterModule()
#   (609): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (610): Identity()
#   (611): ParameterModule()
#   (612): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (613): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (614): ParameterModule()
#   (615): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (616): Identity()
#   (617): ParameterModule()
#   (618): ParameterModule()
#   (619): Identity()
#   (620): ParameterModule()
#   (621): ParameterModule()
#   (622): Identity()
#   (623): ParameterModule()
#   (624): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (625): Identity()
#   (626): ParameterModule()
#   (627): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (628): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (629): ParameterModule()
#   (630): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (631): Identity()
#   (632): ParameterModule()
#   (633): ParameterModule()
#   (634): Identity()
#   (635): ParameterModule()
#   (636): ParameterModule()
#   (637): Identity()
#   (638): ParameterModule()
#   (639): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (640): Identity()
#   (641): ParameterModule()
#   (642): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (643): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (644): ParameterModule()
#   (645): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (646): Identity()
#   (647): ParameterModule()
#   (648): ParameterModule()
#   (649): Identity()
#   (650): ParameterModule()
#   (651): ParameterModule()
#   (652): Identity()
#   (653): ParameterModule()
#   (654): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (655): Identity()
#   (656): ParameterModule()
#   (657): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (658): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (659): ParameterModule()
#   (660): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (661): Identity()
#   (662): ParameterModule()
#   (663): ParameterModule()
#   (664): Identity()
#   (665): ParameterModule()
#   (666): ParameterModule()
#   (667): Identity()
#   (668): ParameterModule()
#   (669): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (670): Identity()
#   (671): ParameterModule()
#   (672): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (673): Linear(in_features=2304, out_features=1108, bias=True)
# )], add_time=True, silent=False, cb_fns_registered=True)

# %%
test_df = pd.read_csv(f'{BASE_DIR}/test.csv')
proc_test_df = generate_df(test_df.copy(), sample_num=[1])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds, _ = learn.get_preds(DatasetType.Test)
preds_ = preds.argmax(dim=-1)

# %%
proc_test_df = generate_df(test_df.copy(), sample_num=[2])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds2, _ = learn.get_preds(DatasetType.Test)
preds2_ = preds2.argmax(dim=-1)

# %%
preds_mean = (preds + preds2)/2.

# %%
## local CV: 0.46 single site
sub_s1_df = generate_submission(preds, name='submission-effB4-384-singlesite.csv')
sub_s1_df.head()

# %%
## local CV: 0.46
sub_2site_df = generate_submission(preds_mean, name='submission-effB4-384-doublesite.csv')

sub_2site_df.head(10)
# Out:
#           id_code  sirna
# 0  HEPG2-08_1_B03    468
# 1  HEPG2-08_1_B04      7
# 2  HEPG2-08_1_B05   1091
# 3  HEPG2-08_1_B06    908
# 4  HEPG2-08_1_B07    135
# 5  HEPG2-08_1_B08    981
# 6  HEPG2-08_1_B09    118
# 7  HEPG2-08_1_B10    638
# 8  HEPG2-08_1_B11    807
# 9  HEPG2-08_1_B12    778

# %%
## local CV: 0.59 single site
sub_s1_df = generate_submission(preds, name='submission-effB6-512-singlesite.csv')
sub_s1_df.head()
# Out:
# write to submission_df submission-effB6-512-singlesite.csv
#           id_code  sirna
# 0  HEPG2-08_1_B03    381
# 1  HEPG2-08_1_B04    637
# 2  HEPG2-08_1_B05    506
# 3  HEPG2-08_1_B06    609
# 4  HEPG2-08_1_B07     43

# %%
## local CV: 0.59
sub_2site_df = generate_submission(preds_mean, name='submission-effB6-512-doublesite.csv')
sub_2site_df.head(10)
# Out:
# write to submission_df submission-effB6-512-doublesite.csv
#           id_code  sirna
# 0  HEPG2-08_1_B03    381
# 1  HEPG2-08_1_B04    637
# 2  HEPG2-08_1_B05    506
# 3  HEPG2-08_1_B06    706
# 4  HEPG2-08_1_B07     43
# 5  HEPG2-08_1_B08     37
# 6  HEPG2-08_1_B09    430
# 7  HEPG2-08_1_B10    638
# 8  HEPG2-08_1_B11    154
# 9  HEPG2-08_1_B12   1064

# %% [markdown]
# ### try TTA

# %%
proc_test_df = generate_df(test_df.copy(), sample_num=[1])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds_tta, _ = learn.TTA(ds_type=DatasetType.Test)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1832' class='' max='2488', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.63% [1832/2488 07:49<02:48]
#     </div>

# %%
## local CV: 0.59 single site + TTA
sub_s1_tta_df = generate_submission(preds_tta, name='submission-effB6-512-TTA-singlesite.csv')
sub_s1_tta_df.head()

# %%
proc_test_df = generate_df(test_df.copy(), sample_num=[2])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds2_tta, _ = learn.TTA(ds_type=DatasetType.Test)
preds_tta_mean = (preds_tta + preds2_tta)/2.

# %%
## local CV: 0.59 double site + TTA
sub_2sites_tta_df = generate_submission(preds_tta_mean, name='submission-effB6-512-TTA-doublesite.csv')
sub_2sites_tta_df.head()

# %% [markdown]
# ## two sites model

# %%
image_size=512
proc_train_s2_df = generate_df(train_df, sample_num=[2], exp=None, test_size=0.2, random_state=2)
tfms2 = get_transforms(do_flip=True, flip_vert=True,
                      max_lighting=0.2, p_lighting=0.5, 
                      max_warp=0.05, max_rotate=20., max_zoom=1.1)

data = (MultiChannelImageList.from_df(df=proc_train_s2_df,path='../DATA/kaggle-2019Q3-cellular/train/')
        .split_from_df(col=2)
        .label_from_df()
        .transform(tfms2,size=image_size)
        .databunch(bs=8,num_workers=8)
        .normalize(stats)
       )

learn = Learner(data, 
                effnetb6, opt_func=optar,
                metrics = [accuracy], 
                model_dir='./fastaimodels').to_fp16()
# learn.model = torch.nn.DataParallel(learn.model)
learn.path = Path('./effb6-gce')
learn.load('effnetb6-512-s2-stage3')


test_df = pd.read_csv(f'{BASE_DIR}/test.csv')
proc_test_df = generate_df(test_df.copy(), sample_num=[1])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds_s2, _ = learn.get_preds(DatasetType.Test)
preds_s2_ = preds_s2.argmax(dim=-1)

proc_test_df = generate_df(test_df.copy(), sample_num=[2])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds2_s2, _ = learn.get_preds(DatasetType.Test)
preds2_s2_ = preds2_s2.argmax(dim=-1)

# %%
image_size=512
proc_train_s1_df = generate_df(train_df, sample_num=[1], exp=None, test_size=0.2, random_state=2)
tfms2 = get_transforms(do_flip=True, flip_vert=True,
                      max_lighting=0.2, p_lighting=0.5, 
                      max_warp=0.05, max_rotate=20., max_zoom=1.1)

data = (MultiChannelImageList.from_df(df=proc_train_s1_df,path='../DATA/kaggle-2019Q3-cellular/train/')
        .split_from_df(col=2)
        .label_from_df()
        .transform(tfms2,size=image_size)
        .databunch(bs=8,num_workers=8)
        .normalize(stats)
       )

learn = Learner(data, 
                effnetb6, opt_func=optar,
                metrics = [accuracy], 
                model_dir='./fastaimodels').to_fp16()
# learn.model = torch.nn.DataParallel(learn.model)
learn.path = Path('./effb6-gce')
learn.load('effnetb6-512-s1-stage3')


test_df = pd.read_csv(f'{BASE_DIR}/test.csv')
proc_test_df = generate_df(test_df.copy(), sample_num=[1])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds_s1, _ = learn.get_preds(DatasetType.Test)
preds_s1_ = preds_s1.argmax(dim=-1)

proc_test_df = generate_df(test_df.copy(), sample_num=[2])
data_test = MultiChannelImageList.from_df(df=proc_test_df,path=f'{BASE_DIR}/test/')
learn.data.add_test(data_test)
preds2_s1, _ = learn.get_preds(DatasetType.Test)
preds2_s1_ = preds2_s1.argmax(dim=-1)

# %%
## local CV: 0.59
preds_mean = (preds_s1 + preds2_s1 + preds_s2 + preds2_s2)/4.
sub_model2site_df = generate_submission(preds_mean, name='submission-effB6-512-2sites.doublesite.csv')
sub_model2site_df.head(10)

# %% [markdown]
# ## self-boost

# %%
sub_df = pd.read_csv('submission-431.csv')

# %%
plate_groups = np.zeros((1108,4), int)
for sirna in range(1108):
    grp = train_df.loc[train_df.sirna==sirna,:].plate.value_counts().index.values
    assert len(grp) == 3
    plate_groups[sirna,0:3] = grp
    plate_groups[sirna,3] = 10 - grp.sum()
    


all_test_exp = test_df.experiment.unique()
group_plate_probs = np.zeros((len(all_test_exp),4))
for idx in range(len(all_test_exp)):
    preds = sub_df.loc[test_df.experiment == all_test_exp[idx],'sirna'].values
    pp_mult = np.zeros((len(preds),1108))
    pp_mult[range(len(preds)),preds] = 1
    
    sub_test = test_df.loc[test_df.experiment == all_test_exp[idx],:]
    assert len(pp_mult) == len(sub_test)
    
    for j in range(4):
        mask = np.repeat(plate_groups[np.newaxis, :, j], len(pp_mult), axis=0) == \
               np.repeat(sub_test.plate.values[:, np.newaxis], 1108, axis=1)
        
        group_plate_probs[idx,j] = np.array(pp_mult)[mask].sum()/len(pp_mult)

exp_to_group = group_plate_probs.argmax(1)
print(exp_to_group)


def select_plate_group(pp_mult, idx, 
                       test_df=test_df, all_test_exp=all_test_exp, plate_groups=plate_groups,
                       exp_to_group=exp_to_group):
    sub_test = test_df.loc[test_df.experiment == all_test_exp[idx],:]
    assert len(pp_mult) == len(sub_test)
    mask = np.repeat(plate_groups[np.newaxis, :, exp_to_group[idx]], len(pp_mult), axis=0) != \
           np.repeat(sub_test.plate.values[:, np.newaxis], 1108, axis=1)
    pp_mult[mask] = 0
    return pp_mult
# Out:
# [3 1 0 0 0 0 2 2 3 0 0 3 1 0 0 0 2 3]

# %%
def apply_boost(sub_df, preds_mean, 
                all_test_exp=all_test_exp, test_df=test_df, 
                plate_groups=plate_groups, exp_to_group=exp_to_group):
    for idx in range(len(all_test_exp)):
        #print('Experiment', idx)
        indices = (test_df.experiment == all_test_exp[idx])

        preds_slice = preds_mean.numpy()[indices,:].copy()

        preds_slice = select_plate_group(preds_slice, idx, 
                                         test_df=test_df, all_test_exp=all_test_exp, plate_groups=plate_groups,
                                         exp_to_group=exp_to_group)
        sub_df.loc[indices,'sirna'] = preds_slice.argmax(1)

    return sub_df

# %%
sub_df = apply_boost(sub_df, preds_mean)
sub_df.to_csv('submission-effB6-512-doublesite.boosted431.csv',index=False)
sub_df.head()

# %%
sub_df = apply_boost(sub_df, preds_tta_mean)
sub_df.to_csv('submission-effB6-512-TTA-doublesite.boosted431.csv',index=False)
sub_df.head()
# Out:
# 0.0
